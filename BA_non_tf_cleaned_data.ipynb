# %% [markdown]
# <a href="https://colab.research.google.com/github/tylaar1/PICAR-autopilot/blob/BA-Branch/BA_non_tf_cleaned_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imports

# %%
import os
import pandas as pd
import cv2
import numpy as np

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# # 1) DATA PRE-PROCESSING
#
# a) Load in labels + image file paths
#
# b) combine them into one dataframe
#
# c) EDA - spotted and removed erroneous label (speed = 1.42...)
#
# ## `cleaned_df` is the final df with all of this completed

# %% [markdown]
# ### 1a) load in labels + image file paths

# %%
labels_file_path = '/content/drive/MyDrive/0. MSc MLiS/google SPRING SEMESTER/1. PHYS4036 MLiS2/MLiS2 Project/KAGGLEDATAmachine-learning-in-science-ii-2025/training_norm.csv'
labels_df = pd.read_csv(labels_file_path, index_col='image_id')

# %%
image_folder_path = '/content/drive/MyDrive/0. MSc MLiS/google SPRING SEMESTER/1. PHYS4036 MLiS2/MLiS2 Project/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data'

image_file_paths = [
    os.path.join(image_folder_path, f)
    for f in os.listdir(image_folder_path)
    if f.lower().endswith(('.png', '.jpg', '.jpeg'))
]

image_file_paths.sort(key=lambda x: int(os.path.splitext(os.path.basename(x))[0])) # sorts the files in the right order (1.png, 2.png, 3.png, ...)

imagefilepaths_df = pd.DataFrame(
    image_file_paths,
    columns=['image_file_paths'],
    index=[int(os.path.splitext(os.path.basename(path))[0]) for path in image_file_paths]
)

imagefilepaths_df.index.name = 'image_id'

# %% [markdown]
# Checking labels dataframe

# %%
labels_df.head()
# Out:
#            angle  speed
# image_id
# 1         0.4375    0.0
# 2         0.8125    1.0
# 3         0.4375    1.0
# 4         0.6250    1.0
# 5         0.5000    0.0

# %% [markdown]
# Checking image file paths dataframe - as you can see the file paths are ordered correctly (1.png, 2.png, 3.png, ...)

# %%
imagefilepaths_df.head()
# Out:
#                                                                                                                                                                    image_file_paths
# image_id
# 1         /content/drive/MyDrive/0. MSc MLiS/google SPRING SEMESTER/1. PHYS4036 MLiS2/MLiS2 Project/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data/1.png
# 2         /content/drive/MyDrive/0. MSc MLiS/google SPRING SEMESTER/1. PHYS4036 MLiS2/MLiS2 Project/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data/2.png
# 3         /content/drive/MyDrive/0. MSc MLiS/google SPRING SEMESTER/1. PHYS4036 MLiS2/MLiS2 Project/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data/3.png
# 4         /content/drive/MyDrive/0. MSc MLiS/google SPRING SEMESTER/1. PHYS4036 MLiS2/MLiS2 Project/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data/4.png
# 5         /content/drive/MyDrive/0. MSc MLiS/google SPRING SEMESTER/1. PHYS4036 MLiS2/MLiS2 Project/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data/5.png

# %% [markdown]
# ### 1b) Combine labels and image file paths into one dataframe

# %%
merged_df = pd.merge(labels_df, imagefilepaths_df, on='image_id', how='inner')
merged_df['speed'] = merged_df['speed'].round(6) # to get rid of floating point errors

# %%
merged_df.head()
# Out:
#            angle  speed  \
# image_id
# 1         0.4375    0.0
# 2         0.8125    1.0
# 3         0.4375    1.0
# 4         0.6250    1.0
# 5         0.5000    0.0
#
#                                                                                                                                                                    image_file_paths
# image_id
# 1         /content/drive/MyDrive/0. MSc MLiS/google SPRING SEMESTER/1. PHYS4036 MLiS2/MLiS2 Project/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data/1.png
# 2         /content/drive/MyDrive/0. MSc MLiS/google SPRING SEMESTER/1. PHYS4036 MLiS2/MLiS2 Project/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data/2.png
# 3         /content/drive/MyDrive/0. MSc MLiS/google SPRING SEMESTER/1. PHYS4036 MLiS2/MLiS2 Project/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data/3.png
# 4         /content/drive/MyDrive/0. MSc MLiS/google SPRING SEMESTER/1. PHYS4036 MLiS2/MLiS2 Project/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data/4.png
# 5         /content/drive/MyDrive/0. MSc MLiS/google SPRING SEMESTER/1. PHYS4036 MLiS2/MLiS2 Project/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data/5.png

# %%
merged_df.loc[3139:3143]
# Out:
#           angle  speed  \
# image_id
# 3139      0.750    1.0
# 3140      0.875    1.0
# 3142      0.625    0.0
# 3143      0.625    1.0
#
#                                                                                                                                                                       image_file_paths
# image_id
# 3139      /content/drive/MyDrive/0. MSc MLiS/google SPRING SEMESTER/1. PHYS4036 MLiS2/MLiS2 Project/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data/3139.png
# 3140      /content/drive/MyDrive/0. MSc MLiS/google SPRING SEMESTER/1. PHYS4036 MLiS2/MLiS2 Project/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data/3140.png
# 3142      /content/drive/MyDrive/0. MSc MLiS/google SPRING SEMESTER/1. PHYS4036 MLiS2/MLiS2 Project/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data/3142.png
# 3143      /content/drive/MyDrive/0. MSc MLiS/google SPRING SEMESTER/1. PHYS4036 MLiS2/MLiS2 Project/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data/3143.png

# %% [markdown]
# The above cell shows that:
#
#  1) the image files and labels match (see image_id and the number at the end of the file path)
#
#  2) the missing rows in labels_df (image_id: 3141, 3999, 4895, 8285, 10171) have been taken care of

# %% [markdown]
# ### 1c) EDA

# %%
merged_df.value_counts('speed')
# Out:
# speed
# 1.000000    10402
# 0.000000     3390
# 1.428571        1
# Name: count, dtype: int64

# %% [markdown]
# note: imbalance datset

# %% [markdown]
# identifying the row with the erroneous speed value

# %%
merged_df[merged_df['speed'] == 1.428571]
# Out:
#            angle     speed  \
# image_id
# 3884      0.4375  1.428571
#
#                                                                                                                                                                       image_file_paths
# image_id
# 3884      /content/drive/MyDrive/0. MSc MLiS/google SPRING SEMESTER/1. PHYS4036 MLiS2/MLiS2 Project/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data/3884.png

# %% [markdown]
# we want to remove this row

# %%
cleaned_df = merged_df[merged_df['speed'] != 1.428571]
cleaned_df.loc[3882:3886]
# Out:
#            angle  speed  \
# image_id
# 3882      0.5625    1.0
# 3883      0.3750    0.0
# 3885      0.0000    1.0
# 3886      0.7500    1.0
#
#                                                                                                                                                                       image_file_paths
# image_id
# 3882      /content/drive/MyDrive/0. MSc MLiS/google SPRING SEMESTER/1. PHYS4036 MLiS2/MLiS2 Project/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data/3882.png
# 3883      /content/drive/MyDrive/0. MSc MLiS/google SPRING SEMESTER/1. PHYS4036 MLiS2/MLiS2 Project/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data/3883.png
# 3885      /content/drive/MyDrive/0. MSc MLiS/google SPRING SEMESTER/1. PHYS4036 MLiS2/MLiS2 Project/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data/3885.png
# 3886      /content/drive/MyDrive/0. MSc MLiS/google SPRING SEMESTER/1. PHYS4036 MLiS2/MLiS2 Project/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data/3886.png

# %% [markdown]
# Save the dataframe as a csv

# %%
# cleaned_df.to_csv("mlis2_cleaned_df.csv", index=True)

# %% [markdown]
# # Speed Classification Data

# %%
classification_df = cleaned_df[['speed','image_file_paths']]
classification_df.head()
# Out:
#           speed  \
# image_id
# 1           0.0
# 2           1.0
# 3           1.0
# 4           1.0
# 5           0.0
#
#                                                                                                                                                                    image_file_paths
# image_id
# 1         /content/drive/MyDrive/0. MSc MLiS/google SPRING SEMESTER/1. PHYS4036 MLiS2/MLiS2 Project/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data/1.png
# 2         /content/drive/MyDrive/0. MSc MLiS/google SPRING SEMESTER/1. PHYS4036 MLiS2/MLiS2 Project/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data/2.png
# 3         /content/drive/MyDrive/0. MSc MLiS/google SPRING SEMESTER/1. PHYS4036 MLiS2/MLiS2 Project/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data/3.png
# 4         /content/drive/MyDrive/0. MSc MLiS/google SPRING SEMESTER/1. PHYS4036 MLiS2/MLiS2 Project/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data/4.png
# 5         /content/drive/MyDrive/0. MSc MLiS/google SPRING SEMESTER/1. PHYS4036 MLiS2/MLiS2 Project/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data/5.png

# %% [markdown]
# # Angle Regression Data

# %%
regression_df = cleaned_df[['angle','image_file_paths']]
regression_df.head()
# Out:
#            angle  \
# image_id
# 1         0.4375
# 2         0.8125
# 3         0.4375
# 4         0.6250
# 5         0.5000
#
#                                                                                                                                                                    image_file_paths
# image_id
# 1         /content/drive/MyDrive/0. MSc MLiS/google SPRING SEMESTER/1. PHYS4036 MLiS2/MLiS2 Project/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data/1.png
# 2         /content/drive/MyDrive/0. MSc MLiS/google SPRING SEMESTER/1. PHYS4036 MLiS2/MLiS2 Project/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data/2.png
# 3         /content/drive/MyDrive/0. MSc MLiS/google SPRING SEMESTER/1. PHYS4036 MLiS2/MLiS2 Project/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data/3.png
# 4         /content/drive/MyDrive/0. MSc MLiS/google SPRING SEMESTER/1. PHYS4036 MLiS2/MLiS2 Project/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data/4.png
# 5         /content/drive/MyDrive/0. MSc MLiS/google SPRING SEMESTER/1. PHYS4036 MLiS2/MLiS2 Project/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data/5.png

# %% [markdown]
# # Resizing images

# %%
resized_shape = (220,220)

images = []

i=0
for f in cleaned_df['image_file_paths']:
  img = cv2.imread(f)
  img = cv2.resize(img, resized_shape)
  img = img / 255.0 # normalise pixel values to range [0,1]
  images.append(img)
  i+=1
  if i%100 == 0:
    print(f"i = {i}")

images = np.array(images, dtype=np.float32)
print(images.shape)  # Expected: (num_images, 220, 220, 3)

file_path = r"G:\My Drive\0. MSc MLiS\google SPRING SEMESTER\1. PHYS4036 MLiS2\MLiS2 Project\images_data.npy"
np.save(file_path, images)

print(f"Image data saved to '{file_path}'")
# Out:
# i = 100

# %% [markdown]
# # STUFF BELOW HERE IS FROM WHEN I WAS EDITING THIS NOTEBOOK LAST WEEK SO FEEL FREE TO IGNORE

# %% [markdown]
# # resizing images

# %%
# using df with just 100 elements (instead of 13.8k) so computation is quicker while im trying to figure out what works

trial_df = concat_df[:100]
trial_df.head(5)
# Out:
#    image_id   angle  speed                                   image_file_paths
# 0         1  0.4375    0.0  /content/drive/MyDrive/0. MSc MLiS/google SPRI...
# 1         2  0.8125    1.0  /content/drive/MyDrive/0. MSc MLiS/google SPRI...
# 2         3  0.4375    1.0  /content/drive/MyDrive/0. MSc MLiS/google SPRI...
# 3         4  0.6250    1.0  /content/drive/MyDrive/0. MSc MLiS/google SPRI...
# 4         5  0.5000    0.0  /content/drive/MyDrive/0. MSc MLiS/google SPRI...

# %%
import cv2

im_size = 220

images = []

for path in trial_df['image_file_paths']:
  img = cv2.imread(path)
  img = cv2.resize(img, (im_size, im_size)) / 255.0 # div by 255 so numbers are all [0,1]
  images.append(img)

# %%
images[0].shape
# Out:
# (220, 220, 3)

# %% [markdown]
# # train, test split

# %%
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

images = trial_df['image_file_paths'].values
y = trial_df[['angle', 'speed']].values  # Both angle and speed as labels

# Shuffle the dataset (images and labels are shuffled together)
images, y = shuffle(images, y, random_state=1)

# Split the dataset into training and test sets
train_x, test_x, train_y, test_y = train_test_split(images, y, test_size=0.2, random_state=1)

# Check the shapes of the split data
print(f"Training data (X) shape: {train_x.shape}")
print(f"Testing data (X) shape: {test_x.shape}")
print(f"Training labels (y) shape: {train_y.shape}")
print(f"Testing labels (y) shape: {test_y.shape}")
# Out:
# Training data (X) shape: (80,)
# Testing data (X) shape: (20,)
# Training labels (y) shape: (80, 2)
# Testing labels (y) shape: (20, 2)

# %%
train_y[0]
# Out:
# array([0.875, 0.   ])

# %% [markdown]
# # 1) THE MODEL

# %%
import tensorflow as tf

# %%
num_channels = 3 # RGB
img_size = 220
num_outputs = 2 # angle and speed

# Model input
x = tf.keras.Input(shape=(img_size, img_size, num_channels), dtype=tf.float32)
y = tf.keras.Input(shape=(num_outputs,), dtype=tf.float32)

# %%
dropoutrate = 0.2
num_outputs = 2
input_shape = [224,224,3]

mbnet = tf.keras.applications.MobileNetV2(input_shape=input_shape, include_top=False, weights='imagenet') #We now dont want randomized weights but to load weights from imagenet

model = tf.keras.Sequential([
  mbnet,
  tf.keras.layers.GlobalAveragePooling2D(),
  tf.keras.layers.Dropout(dropoutrate),
  tf.keras.layers.Dense(num_outputs, activation='mse')
])
model.build()

mbnet.trainable = False # freeze the first layers to the imagenet weights

model.summary() # print the model
