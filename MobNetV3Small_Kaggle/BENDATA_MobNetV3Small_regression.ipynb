# %% [markdown]
# # SWITCH TO **`T4 GPU`** OR THE **`HPC`**

# %% [markdown]
# # Imports

# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.preprocessing.image import load_img, img_to_array
from sklearn.model_selection import train_test_split
from sklearn.metrics import balanced_accuracy_score
import matplotlib.pyplot as plt
import re
from keras.callbacks import ModelCheckpoint, LambdaCallback
from PIL import Image
# Out:
# 2025-05-04 22:54:39.316571: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-04 22:54:39.351114: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-04 22:54:39.352022: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-05-04 22:54:39.939264: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
import platform
print(platform.system())
# Out:
# Linux

# %%
# makes it so pd dfs aren't truncated

pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# # 1) DATA PRE-PROCESSING
#
# a) Load in kaggle data labels + image file paths
#
# b) combine kaggle data labels and image file paths into one dataframe
#
# c) load in the extra 486 image file paths
#
# d) extract the speed and angle labels from the file path names
#
# e) store that extra data in a pandas df and do the value normalisation
#
# f) merge the kaggle and extra data dfs
#
# g) EDA
#
# h) convert the images to numerical RGB feature maps
#
# i) split data into training-validation sets
#
# j) data augmentation applied to training set

# %% [markdown]
# ### 1a) load in kaggle data labels + image file paths

# %%
# labels_file_path = '/content/drive/MyDrive/machine-learning-in-science-ii-2025/training_norm.csv' # tylers file path
labels_file_path = '/home/apyba3/KAGGLEDATAmachine-learning-in-science-ii-2025/training_norm.csv' # ben hpc file path (mlis2 cluster)
# labels_file_path = '/home/ppytr13/machine-learning-in-science-ii-2025/training_norm.csv' # tyler hpc file path (mlis2 cluster)
labels_df = pd.read_csv(labels_file_path, index_col='image_id')

# %%
image_folder_path = '/home/apyba3/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data' # OG data ben hpc file path (mlis2 cluster)
# image_folder_path = '/home/ppytr13/machine-learning-in-science-ii-2025//training_data/training_data'
# image_folder_path = '/content/drive/MyDrive/machine-learning-in-science-ii-2025/training_data/training_data' # tylers file path
image_file_paths = [
    os.path.join(image_folder_path, f)
    for f in os.listdir(image_folder_path)
    if f.lower().endswith(('.png', '.jpg', '.jpeg'))
]

image_file_paths.sort(key=lambda x: int(os.path.splitext(os.path.basename(x))[0])) # sorts the files in the right order (1.png, 2.png, 3.png, ...)

imagefilepaths_df = pd.DataFrame(
    image_file_paths,
    columns=['image_file_paths'],
    index=[int(os.path.splitext(os.path.basename(path))[0]) for path in image_file_paths]
)

imagefilepaths_df.index.name = 'image_id'

# %% [markdown]
# Checking labels dataframe

# %%
labels_df.head()
# Out:
#            angle  speed
# image_id
# 1         0.4375    0.0
# 2         0.8125    1.0
# 3         0.4375    1.0
# 4         0.6250    1.0
# 5         0.5000    0.0

# %% [markdown]
# Checking image file paths dataframe - as you can see the file paths are ordered correctly (1.png, 2.png, 3.png, ...)

# %%
imagefilepaths_df.head()
# Out:
#                                                                                       image_file_paths
# image_id
# 1         /home/apyba3/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data/1.png
# 2         /home/apyba3/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data/2.png
# 3         /home/apyba3/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data/3.png
# 4         /home/apyba3/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data/4.png
# 5         /home/apyba3/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data/5.png

# %% [markdown]
# ### 1b) Combine the kaggle labels and image file paths into one dataframe

# %%
kaggle_df = pd.merge(labels_df, imagefilepaths_df, on='image_id', how='inner')
kaggle_df['speed'] = kaggle_df['speed'].round(6) # to get rid of floating point errors

# %%
kaggle_df.tail()
# Out:
#            angle  speed  \
# image_id
# 13794     0.6250    1.0
# 13795     0.4375    1.0
# 13796     0.5625    0.0
# 13797     0.6250    0.0
# 13798     0.6875    1.0
#
#                                                                                           image_file_paths
# image_id
# 13794     /home/apyba3/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data/13794.png
# 13795     /home/apyba3/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data/13795.png
# 13796     /home/apyba3/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data/13796.png
# 13797     /home/apyba3/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data/13797.png
# 13798     /home/apyba3/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data/13798.png

# %%
kaggle_df.loc[3139:3143]
# Out:
#           angle  speed  \
# image_id
# 3139      0.750    1.0
# 3140      0.875    1.0
# 3142      0.625    0.0
# 3143      0.625    1.0
#
#                                                                                          image_file_paths
# image_id
# 3139      /home/apyba3/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data/3139.png
# 3140      /home/apyba3/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data/3140.png
# 3142      /home/apyba3/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data/3142.png
# 3143      /home/apyba3/KAGGLEDATAmachine-learning-in-science-ii-2025/training_data/training_data/3143.png

# %% [markdown]
# The above cell shows that:
#
#  1) the image files and labels match (see image_id and the number at the end of the file path)
#
#  2) the missing rows in labels_df (image_id: 3141, 3999, 4895, 8285, 10171) have been taken care of

# %% [markdown]
# ### 1c) load in the extra 486 labels image file paths

# %%
petrudata_folder_path = '/home/apyba3/petru_data'
bendata_folder_path = '/home/apyba3/bendata_1st_set'

# %%
def extract_filepaths(extradata_folderpath):
    extradata_file_paths = [
    os.path.join(extradata_folderpath, f)
    for f in os.listdir(extradata_folderpath)
    if f.lower().endswith(('.png', '.jpg', '.jpeg'))
    ]
    return extradata_file_paths

# %% [markdown]
# ### 1d) extract the speed and angle labels from the file path names

# %% [markdown]
# image file path name follows the pattern: `randomnumber_angle_speed`

# %%
def loadin_extradata(extradata_folderpath):
    extracted_filepaths = extract_filepaths(extradata_folderpath)
    # Regex pattern to extract angle and speed values
    pattern = r'(\d+)_(\d+)_(\d+)\.png'  # Fixed pattern to capture groups correctly

    angle_value = []
    speed_value = []

    # Loop through file paths and extract angle and speed values
    for file_path in extracted_filepaths:
        match = re.search(pattern, file_path)
        if match:
            # Extract random number, angle, and speed values
            random_number = match.group(1)
            angle_value.append(int(match.group(2)))
            speed_value.append(int(match.group(3)))
        else:
            print(f"No match found for file: {file_path}")

    return angle_value, speed_value

# %% [markdown]
# checking it has stored the labels correctly (check if the angle_value order matches that of the file path)

# %% [markdown]
# ### 1e) store that extra data in a pandas df and do the value normalisation

# %%
def create_df_and_normalisation(folder_path):
    max_image_id = len(loadin_extradata(folder_path)[0])
    df = pd.DataFrame(
        {
            'angle': loadin_extradata(folder_path)[0],
            'speed': loadin_extradata(folder_path)[1],
            'image_file_paths': extract_filepaths(folder_path)
        }
    )

    df.loc[df['speed'] > 0, 'speed'] = 1
    df['angle'] = (df['angle'] - 50)/80
    return df

def combine_dfs_add_imageid(df1, df2):
    combined_df = pd.concat([df1, df2], ignore_index=True)
    combined_df.index = pd.RangeIndex(start=13799, stop=13799 + len(combined_df), step=1)
    combined_df.index.name = 'image_id'
    return combined_df

bendata_df = create_df_and_normalisation(bendata_folder_path)
petrudata_df = create_df_and_normalisation(petrudata_folder_path)

combinedextradata_df = combine_dfs_add_imageid(bendata_df, petrudata_df)
display(combinedextradata_df.tail())
# Out:
#            angle  speed                                  image_file_paths
# image_id
# 16402     0.3125      1   /home/apyba3/petru_data/1712922464963_75_35.png
# 16403     0.5625      1   /home/apyba3/petru_data/1712918948764_95_35.png
# 16404     0.3125      1   /home/apyba3/petru_data/1712921132962_75_35.png
# 16405     0.7500      1  /home/apyba3/petru_data/1712917893422_110_35.png
# 16406     0.1250      1   /home/apyba3/petru_data/1712918494936_60_35.png

# %% [markdown]
# ### 1f) merge the kaggle and extra data dfs

# %%
merged_df = pd.concat([kaggle_df, combinedextradata_df])

# %% [markdown]
# ### 1g) check for corrupted images and get rid of them

# %%
def validate_image_files(dataframe):
    """
    Check each image file in the dataframe and return a new dataframe with only valid files.
    Also prints information about invalid files.
    """
    valid_rows = []
    invalid_files = []
    
    print(f"Checking {len(dataframe)} image files...")
    
    for index, row in dataframe.iterrows():
        path = row['image_file_paths']
        
        # # Print every 100 files to show progress
        # if len(valid_rows) % 100 == 0 and len(valid_rows) > 0:
        #     print(f"Processed {len(valid_rows) + len(invalid_files)} files, {len(valid_rows)} valid...")
        
        try:
            # Basic file checks
            if not os.path.exists(path):
                # print(f"File does not exist: {path}")
                invalid_files.append(path)
                continue
                
            if os.path.getsize(path) == 0:
                # print(f"File is empty: {path}")
                invalid_files.append(path)
                continue
            
            # Try to open the image with PIL to verify it's valid
            with Image.open(path) as img:
                # Just accessing img.size will verify the image can be read
                width, height = img.size
            
            # If we get this far, the image is valid
            valid_rows.append(row)
                
        except Exception as e:
            print(f"Error with {path}: {e}")
            invalid_files.append(path)
    
    # Create a new dataframe with only valid rows
    valid_df = pd.DataFrame(valid_rows)
    
    print(f"\nValidation complete: {len(valid_df)} valid files, {len(invalid_files)} invalid files")
    
    # if invalid_files:
    #     print("\nFirst few invalid files:")
    #     for path in invalid_files[:5]:
    #         print(f"  - {path}")
    
    return valid_df

# Run the validation
valid_df = validate_image_files(merged_df)
# Out:
# Checking 16401 image files...
#
# Validation complete: 16373 valid files, 28 invalid files

# %% [markdown]
# ### 1h) EDA

# %%
# Get value counts
speed_counts = valid_df['speed'].value_counts().sort_index()
angle_counts = valid_df['angle'].value_counts().sort_index()

# Create subplots with custom width ratios
fig, axes = plt.subplots(1, 2, figsize=(6, 4), gridspec_kw={'width_ratios': [1,4]})  # Speed plot narrower

# Plot speed
speed_counts.plot(kind='bar', edgecolor='black', ax=axes[0])
# axes[0].set_title('Speed', fontsize=15)
axes[0].set_xlabel('Speed', fontsize=17)
axes[0].set_ylabel('Count', fontsize=17)
axes[0].tick_params(axis='both', labelsize=15)
axes[0].grid(axis='y', linestyle='--', alpha=0.7)

# Plot angle
angle_counts.plot(kind='bar', edgecolor='black', ax=axes[1])
# axes[1].set_title('Angle', fontsize=15)
axes[1].set_xlabel('Angle', fontsize=17, labelpad=22)
# axes[1].set_ylabel('Count', fontsize=17)
axes[1].tick_params(axis='both', labelsize=15)
axes[1].grid(axis='y', linestyle='--', alpha=0.7)

# Adjust layout and save
plt.tight_layout()
plt.savefig('speed_angle_distribution.pdf', format='pdf')
plt.show()

# %%
valid_df.value_counts('angle').sort_index()
# Out:
# angle
# 0.0000      87
# 0.0625      62
# 0.1250     251
# 0.1875     246
# 0.2500     260
# 0.3125     311
# 0.3750     557
# 0.4375    1622
# 0.5000    2503
# 0.5625    1882
# 0.6250    2121
# 0.6875    2223
# 0.7500    2477
# 0.8125    1279
# 0.8750     359
# 0.9375      89
# 1.0000      44
# Name: count, dtype: int64

# %% [markdown]
# note: imbalance datset

# %% [markdown]
# we want to remove the row containing the erroneous 1.428571 speed value

# %%
cleaned_df = valid_df[valid_df['speed'] != 1.428571]

# %%
cleaned_df.value_counts('speed')
# Out:
# speed
# 1.0    12553
# 0.0     3819
# Name: count, dtype: int64

# %% [markdown]
# ### 1i) convert images to numerical RGB feature maps

# %%
BATCH_SIZE = 32

# %%
def process_image(image_path, label, resized_shape=(224, 224)):
    image = tf.io.read_file(image_path)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, resized_shape)
    image = image / 255.0  # Normalise pixel values to [0,1]
    return image, label

dataset = tf.data.Dataset.from_tensor_slices((cleaned_df["image_file_paths"], cleaned_df["angle"])) # Convert pd df into a tf ds

dataset = dataset.map(process_image, num_parallel_calls=tf.data.AUTOTUNE)

dataset = dataset.cache()
dataset = dataset.shuffle(len(cleaned_df))
dataset = dataset.batch(BATCH_SIZE)
dataset = dataset.prefetch(tf.data.AUTOTUNE)
# Out:
# 2025-05-04 22:54:46.134852: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1960] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %% [markdown]
# lets check and see if what we have done works

# %%
for images, labels in dataset.take(1):
    print(images.shape, labels.shape)
# Out:
# (32, 224, 224, 3) (32,)

# %% [markdown]
# ### 1j) Splitting data into training and validation sets (test set is already provided in kaggle data)

# %%
# 90-10 split

dataset_size = tf.data.experimental.cardinality(dataset).numpy()
train_size = int(0.85 * dataset_size)

train_dataset = dataset.take(train_size)
val_dataset = dataset.skip(train_size)

# %%
print(f"Train size: {train_size}, validation size: {dataset_size - train_size}")
# Out:
# Train size: 435, validation size: 77

# %% [markdown]
# ### 1k) Data Augmentation applied to training set
#
# - Random Brightness Adjustment
# - Random Contrast Adjustment
# - Random Hue Adjustment
# - Random Saturation Adjustment
# - Random Horizontal Flip

# %%
def augment_image(image, label):
  seed = (6, 9)
  image = tf.image.stateless_random_brightness(image, 0.2, seed)
  image = tf.image.stateless_random_contrast(image, 0.8, 1.2, seed)
  image = tf.image.stateless_random_hue(image, 0.2, seed)
  image = tf.image.stateless_random_saturation(image, 0.8, 1.2, seed)
  image = tf.image.stateless_random_flip_left_right(image, seed)
  return image, label

# Create a dataset of augmented images from the original train_dataset
augmented_dataset = train_dataset.map(augment_image, num_parallel_calls=tf.data.AUTOTUNE)

# Concatenate the original and augmented datasets
train_dataset = train_dataset.concatenate(augmented_dataset)

# Shuffle the combined dataset
train_dataset = train_dataset.shuffle(buffer_size=len(cleaned_df))

# %%
angle_list = []

for image_batch, label_batch in train_dataset:
    angle_list.extend(label_batch.numpy())  # add all 32 values from the batch

angle_distribution = pd.Series(angle_list).value_counts().sort_index()
print(angle_distribution)
# Out:
# 0.0000     147
# 0.0625     105
# 0.1250     433
# 0.1875     418
# 0.2500     442
# 0.3125     536
# 0.3750     950
# 0.4375    2754
# 0.5000    4239
# 0.5625    3197
# 0.6250    3608
# 0.6875    3775
# 0.7500    4225
# 0.8125    2174
# 0.8750     612
# 0.9375     152
# 1.0000      73
# Name: count, dtype: int64

# %% [markdown]
# count how many images are in the training set - 22016 with no extradata and 80-20 split

# %%
total_images = 0
for image_batch, _ in train_dataset:
    total_images += image_batch.shape[0]  # Add the batch size

print(f"Total number of images in train_dataset: {total_images}")
# Out:
# Total number of images in train_dataset: 27840

# %% [markdown]
# checking to see if whats been done was successful or needs debugging

# %%
f, axarr = plt.subplots(1,10)

i = 0
for image_batch, label_batch in train_dataset.take(1):  # Take one batch
    for image in image_batch:  # Iterate through images in the batch
        if i < 10:  # Only display the first 5 images
            print('image shape: ', np.shape(image))
            tf.print('label:', label_batch[i])  # Print label for the corresponding image
            axarr[i].imshow(image)
            axarr[i].axis('off')
            i += 1
        else:
            break  # Stop after displaying 5 images
plt.show()
# Out:
# image shape:  (224, 224, 3)
# label: 0.4375
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# image shape:  (224, 224, 3)
# label: 0.5625
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# image shape:  (224, 224, 3)
# label: 0.3125
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# image shape:  (224, 224, 3)
# label: 0.8125
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# image shape:  (224, 224, 3)
# label: 0.8125
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# image shape:  (224, 224, 3)
# label: 0.625
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# image shape:  (224, 224, 3)
# label: 0.5625
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# image shape:  (224, 224, 3)
# label: 0.625
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# image shape:  (224, 224, 3)
# label: 0.5
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# image shape:  (224, 224, 3)
# label: 0.8125
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # 2) CLASSIFICATION SPEED Model Building - MobNetV3Small Transfer Learning

# %% [markdown]
# ### 2a) Set up model architecture

# %%
dropoutrate = 0.2
input_shape = (224,224,3)
num_classes = 1 # we're only predicting the prob of the positive class

# %%
mobnetv3small = tf.keras.applications.MobileNetV3Small(
    weights = 'imagenet',
    include_top = False,
    input_shape = input_shape
)

model = tf.keras.Sequential([
  mobnetv3small,
  tf.keras.layers.GlobalAveragePooling2D(),
  tf.keras.layers.Dropout(dropoutrate),
  tf.keras.layers.Dense(256, activation='relu'),
  tf.keras.layers.Dropout(dropoutrate),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(dropoutrate),
  tf.keras.layers.Dense(64, activation='relu'),
  tf.keras.layers.Dropout(dropoutrate),
  tf.keras.layers.Dense(32, activation='relu'),
  tf.keras.layers.Dense(num_classes, activation='linear')
])

mobnetv3small.trainable = False  # freeze mobnetv3small layers

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  MobilenetV3small (Function  (None, 7, 7, 576)         939120
#  al)
#
#  global_average_pooling2d (  (None, 576)               0
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 576)               0
#
#  dense (Dense)               (None, 256)               147712
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  dense_4 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 1130097 (4.31 MB)
# Trainable params: 190977 (746.00 KB)
# Non-trainable params: 939120 (3.58 MB)
# _________________________________________________________________

# %% [markdown]
# compile the model

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss=tf.keras.losses.MeanSquaredError(),
)

# %% [markdown]
# ### 2c) train the model with the mobnetv3small layers frozen

# %%
class CustomModelCheckpoint(tf.keras.callbacks.Callback):
    def __init__(self, filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min'):
        super(CustomModelCheckpoint, self).__init__()
        self.filepath = filepath
        self.monitor = monitor
        self.verbose = verbose
        self.save_best_only = save_best_only
        
        # Initialize best value based on mode
        self.mode = mode
        if mode == 'min':
            self.best = float('inf')
            self.monitor_op = lambda current, best: current < best
        else:  # 'max'
            self.best = float('-inf')
            self.monitor_op = lambda current, best: current > best
            
    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        current = logs.get(self.monitor)
        
        if current is None:
            if self.verbose > 0:
                print(f"Warning: {self.monitor} not found in logs")
            return
            
        if self.save_best_only:
            if self.monitor_op(current, self.best):
                if self.verbose > 0:
                    print(f"\nEpoch {epoch+1}: {self.monitor} improved from {self.best:.4f} to {current:.4f}")
                    print(f"Saving model to {self.filepath}")
                self.best = current
                
                # Use direct model.save() without extra parameters
                try:
                    self.model.save(self.filepath)
                except Exception as e:
                    print(f"Error saving model: {e}")
        else:
            if self.verbose > 0:
                print(f"\nEpoch {epoch+1}: saving model to {self.filepath}")
            try:
                self.model.save(self.filepath)
            except Exception as e:
                print(f"Error saving model: {e}")

# %%
# # Define checkpoint directory and create it if it doesn't exist
# checkpoint_dir = '/home/apyba3/PICAR-autopilot/MobNetV3Small_Kaggle/checkpoints'
# os.makedirs(checkpoint_dir, exist_ok=True)

# # Define checkpoint filepath
# checkpoint_filepath = os.path.join(checkpoint_dir, '50epochs_frozen_mobnetv3smallcheckpoint.keras')

# # Create custom checkpoint callback
# custom_checkpoint = CustomModelCheckpoint(
#     filepath=checkpoint_filepath,
#     monitor='val_loss',
#     save_best_only=True,
#     mode='min',
#     verbose=1
# )

# # Define epoch callback 
# epoch_callback = LambdaCallback(
#     on_epoch_begin=lambda epoch, logs: print(f"\nStarting Epoch {epoch + 1}..."),
#     on_epoch_end=lambda epoch, logs: print(f"Completed Epoch {epoch + 1}, Loss: {logs['loss']:.4f}, Val Loss: {logs['val_loss']:.4f}")
# )

# # Training with callbacks
# history = model.fit(
#     train_dataset,
#     validation_data=val_dataset,
#     epochs=50,
#     callbacks=[custom_checkpoint, epoch_callback]
# )

# %%
# Define checkpoint directory and create it if it doesn't exist
checkpoint_dir = '/home/apyba3/PICAR-autopilot/MobNetV3Small_Kaggle/checkpoints'
os.makedirs(checkpoint_dir, exist_ok=True)

# Define checkpoint filepath for the finetuned model
checkpoint_filepath = os.path.join(checkpoint_dir, 'bendata_regression_finetune_earlystop_mbnetv3small_checkpoint.keras')

# Use the existing CustomModelCheckpoint class (no need to redefine it)
# Just create a new instance with the updated filepath
custom_checkpoint = CustomModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_loss',
    save_best_only=True,
    mode='min',
    verbose=1
)

# Define epoch callback 
epoch_callback = LambdaCallback(
    on_epoch_begin=lambda epoch, logs: print(f"\nStarting Epoch {epoch + 1}..."),
    on_epoch_end=lambda epoch, logs: print(f"Completed Epoch {epoch + 1}, Loss: {logs['loss']:.4f}, Val Loss: {logs['val_loss']:.4f}")
)

from keras.callbacks import EarlyStopping

# Define early stopping callback
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=10,
    min_delta=0.001,
    mode='min',
    restore_best_weights=True,  # This loads the best weights into model memory when stopping
    verbose=1
)

# Train with both callbacks
history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=100,
    callbacks=[custom_checkpoint, epoch_callback, early_stopping]
)
# Out:
# Starting Epoch 1...
# Epoch 1/100
# 870/870 [==============================] - ETA: 0s - loss: 0.0317
# Epoch 1: val_loss improved from inf to 0.0316
# Saving model to /home/apyba3/PICAR-autopilot/MobNetV3Small_Kaggle/checkpoints/bendata_regression_finetune_earlystop_mbnetv3small_checkpoint.keras
# Completed Epoch 1, Loss: 0.0317, Val Loss: 0.0316
# 870/870 [==============================] - 79s 80ms/step - loss: 0.0317 - val_loss: 0.0316
#
# Starting Epoch 2...
# Epoch 2/100
# 870/870 [==============================] - ETA: 0s - loss: 0.0230
# Epoch 2: val_loss improved from 0.0316 to 0.0219
# Saving model to /home/apyba3/PICAR-autopilot/MobNetV3Small_Kaggle/checkpoints/bendata_regression_finetune_earlystop_mbnetv3small_checkpoint.keras
# Completed Epoch 2, Loss: 0.0230, Val Loss: 0.0219
# 870/870 [==============================] - 75s 78ms/step - loss: 0.0230 - val_loss: 0.0219
#
# Starting Epoch 3...
# Epoch 3/100
# 870/870 [==============================] - ETA: 0s - loss: 0.0214Completed Epoch 3, Loss: 0.0214, Val Loss: 0.0250
# 870/870 [==============================] - 75s 78ms/step - loss: 0.0214 - val_loss: 0.0250
#
# Starting Epoch 4...
# Epoch 4/100
# 870/870 [==============================] - ETA: 0s - loss: 0.0198
# Epoch 4: val_loss improved from 0.0219 to 0.0159
# Saving model to /home/apyba3/PICAR-autopilot/MobNetV3Small_Kaggle/checkpoints/bendata_regression_finetune_earlystop_mbnetv3small_checkpoint.keras
# Completed Epoch 4, Loss: 0.0198, Val Loss: 0.0159
# 870/870 [==============================] - 75s 78ms/step - loss: 0.0198 - val_loss: 0.0159
#
# Starting Epoch 5...
# Epoch 5/100
# 870/870 [==============================] - ETA: 0s - loss: 0.0189
# Epoch 5: val_loss improved from 0.0159 to 0.0150
# Saving model to /home/apyba3/PICAR-autopilot/MobNetV3Small_Kaggle/checkpoints/bendata_regression_finetune_earlystop_mbnetv3small_checkpoint.keras
# Completed Epoch 5, Loss: 0.0189, Val Loss: 0.0150
# 870/870 [==============================] - 75s 78ms/step - loss: 0.0189 - val_loss: 0.0150
#
# Starting Epoch 6...
# Epoch 6/100
# 870/870 [==============================] - ETA: 0s - loss: 0.0190Completed Epoch 6, Loss: 0.0190, Val Loss: 0.0169
# 870/870 [==============================] - 75s 77ms/step - loss: 0.0190 - val_loss: 0.0169
#
# Starting Epoch 7...
# Epoch 7/100
# 870/870 [==============================] - ETA: 0s - loss: 0.0186Completed Epoch 7, Loss: 0.0186, Val Loss: 0.0151
# 870/870 [==============================] - 75s 77ms/step - loss: 0.0186 - val_loss: 0.0151
#
# Starting Epoch 8...
# Epoch 8/100
# 870/870 [==============================] - ETA: 0s - loss: 0.0180
# Epoch 8: val_loss improved from 0.0150 to 0.0139
# Saving model to /home/apyba3/PICAR-autopilot/MobNetV3Small_Kaggle/checkpoints/bendata_regression_finetune_earlystop_mbnetv3small_checkpoint.keras
# Completed Epoch 8, Loss: 0.0180, Val Loss: 0.0139
# 870/870 [==============================] - 75s 78ms/step - loss: 0.0180 - val_loss: 0.0139
#
# Starting Epoch 9...
# Epoch 9/100
# 870/870 [==============================] - ETA: 0s - loss: 0.0178Completed Epoch 9, Loss: 0.0178, Val Loss: 0.0156
# 870/870 [==============================] - 75s 77ms/step - loss: 0.0178 - val_loss: 0.0156
#
# Starting Epoch 10...
# Epoch 10/100
# 870/870 [==============================] - ETA: 0s - loss: 0.0177Completed Epoch 10, Loss: 0.0177, Val Loss: 0.0157
# 870/870 [==============================] - 75s 77ms/step - loss: 0.0177 - val_loss: 0.0157
#
# Starting Epoch 11...
# Epoch 11/100
# 870/870 [==============================] - ETA: 0s - loss: 0.0176
# Epoch 11: val_loss improved from 0.0139 to 0.0135
# Saving model to /home/apyba3/PICAR-autopilot/MobNetV3Small_Kaggle/checkpoints/bendata_regression_finetune_earlystop_mbnetv3small_checkpoint.keras
# Completed Epoch 11, Loss: 0.0176, Val Loss: 0.0135
# 870/870 [==============================] - 75s 78ms/step - loss: 0.0176 - val_loss: 0.0135
#
# Starting Epoch 12...
# Epoch 12/100
# 870/870 [==============================] - ETA: 0s - loss: 0.0172
# Epoch 12: val_loss improved from 0.0135 to 0.0131
# Saving model to /home/apyba3/PICAR-autopilot/MobNetV3Small_Kaggle/checkpoints/bendata_regression_finetune_earlystop_mbnetv3small_checkpoint.keras
# Completed Epoch 12, Loss: 0.0172, Val Loss: 0.0131
# 870/870 [==============================] - 75s 78ms/step - loss: 0.0172 - val_loss: 0.0131
#
# Starting Epoch 13...
# Epoch 13/100
# 870/870 [==============================] - ETA: 0s - loss: 0.0176Completed Epoch 13, Loss: 0.0176, Val Loss: 0.0151
# 870/870 [==============================] - 75s 78ms/step - loss: 0.0176 - val_loss: 0.0151
#
# Starting Epoch 14...
# Epoch 14/100
# 870/870 [==============================] - ETA: 0s - loss: 0.0171Completed Epoch 14, Loss: 0.0171, Val Loss: 0.0153
# 870/870 [==============================] - 74s 77ms/step - loss: 0.0171 - val_loss: 0.0153
#
# Starting Epoch 15...
# Epoch 15/100
# 870/870 [==============================] - ETA: 0s - loss: 0.0173Completed Epoch 15, Loss: 0.0173, Val Loss: 0.0249
# 870/870 [==============================] - 75s 78ms/step - loss: 0.0173 - val_loss: 0.0249
#
# Starting Epoch 16...
# Epoch 16/100
# 870/870 [==============================] - ETA: 0s - loss: 0.0166
# Epoch 16: val_loss improved from 0.0131 to 0.0121
# Saving model to /home/apyba3/PICAR-autopilot/MobNetV3Small_Kaggle/checkpoints/bendata_regression_finetune_earlystop_mbnetv3small_checkpoint.keras
# Completed Epoch 16, Loss: 0.0166, Val Loss: 0.0121
# 870/870 [==============================] - 75s 78ms/step - loss: 0.0166 - val_loss: 0.0121
#
# Starting Epoch 17...
# Epoch 17/100
# 870/870 [==============================] - ETA: 0s - loss: 0.0167Completed Epoch 17, Loss: 0.0167, Val Loss: 0.0140
# 870/870 [==============================] - 75s 77ms/step - loss: 0.0167 - val_loss: 0.0140
#
# Starting Epoch 18...
# Epoch 18/100
# 870/870 [==============================] - ETA: 0s - loss: 0.0169Completed Epoch 18, Loss: 0.0169, Val Loss: 0.0154
# 870/870 [==============================] - 75s 77ms/step - loss: 0.0169 - val_loss: 0.0154
#
# Starting Epoch 19...
# Epoch 19/100
# 870/870 [==============================] - ETA: 0s - loss: 0.0165Completed Epoch 19, Loss: 0.0165, Val Loss: 0.0142
# 870/870 [==============================] - 74s 77ms/step - loss: 0.0165 - val_loss: 0.0142
#
# Starting Epoch 20...
# Epoch 20/100
# 870/870 [==============================] - ETA: 0s - loss: 0.0163Completed Epoch 20, Loss: 0.0163, Val Loss: 0.0137
# 870/870 [==============================] - 75s 77ms/step - loss: 0.0163 - val_loss: 0.0137
#
# Starting Epoch 21...
# Epoch 21/100
# 870/870 [==============================] - ETA: 0s - loss: 0.0165Completed Epoch 21, Loss: 0.0165, Val Loss: 0.0124
# 870/870 [==============================] - 74s 77ms/step - loss: 0.0165 - val_loss: 0.0124
#
# Starting Epoch 22...
# Epoch 22/100
# 870/870 [==============================] - ETA: 0s - loss: 0.0166Completed Epoch 22, Loss: 0.0166, Val Loss: 0.0137
# 870/870 [==============================] - 75s 77ms/step - loss: 0.0166 - val_loss: 0.0137
#
# Starting Epoch 23...
# Epoch 23/100
# 870/870 [==============================] - ETA: 0s - loss: 0.0163Completed Epoch 23, Loss: 0.0163, Val Loss: 0.0132
# 870/870 [==============================] - 75s 78ms/step - loss: 0.0163 - val_loss: 0.0132
#
# Starting Epoch 24...
# Epoch 24/100
# 870/870 [==============================] - ETA: 0s - loss: 0.0164Completed Epoch 24, Loss: 0.0164, Val Loss: 0.0138
# 870/870 [==============================] - 76s 77ms/step - loss: 0.0164 - val_loss: 0.0138
#
# Starting Epoch 25...
# Epoch 25/100
# 870/870 [==============================] - ETA: 0s - loss: 0.0162
# Epoch 25: val_loss improved from 0.0121 to 0.0120
# Saving model to /home/apyba3/PICAR-autopilot/MobNetV3Small_Kaggle/checkpoints/bendata_regression_finetune_earlystop_mbnetv3small_checkpoint.keras
# Completed Epoch 25, Loss: 0.0162, Val Loss: 0.0120
# 870/870 [==============================] - 75s 78ms/step - loss: 0.0162 - val_loss: 0.0120
#
# Starting Epoch 26...
# Epoch 26/100
# 870/870 [==============================] - ETA: 0s - loss: 0.0161Completed Epoch 26, Loss: 0.0161, Val Loss: 0.0122
# Restoring model weights from the end of the best epoch: 16.
# 870/870 [==============================] - 75s 78ms/step - loss: 0.0161 - val_loss: 0.0122
# Epoch 26: early stopping

# %%
# frozen training results
epochs = list(range(1, 27))  # Epochs 1-26
training_loss = [0.0317, 0.0230, 0.0214, 0.0198, 0.0189, 0.0190, 0.0186, 0.0180, 
                 0.0178, 0.0177, 0.0176, 0.0172, 0.0176, 0.0171, 0.0173, 0.0166, 
                 0.0167, 0.0169, 0.0165, 0.0163, 0.0165, 0.0166, 0.0163, 0.0164,
                 0.0162, 0.0161]
validation_loss = [0.0316, 0.0219, 0.0250, 0.0159, 0.0150, 0.0169, 0.0151, 0.0139,
                   0.0156, 0.0157, 0.0135, 0.0131, 0.0151, 0.0153, 0.0249, 0.0121,
                   0.0140, 0.0154, 0.0142, 0.0137, 0.0124, 0.0137, 0.0132, 0.0138,
                   0.0120, 0.0122]

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_loss_curves(history, save_path=None, fontsize=14):
    """
    Create a professional-looking loss curve plot with training and validation curves.

    Args:
        history: The history object returned by model.fit()
        save_path: Path to save the plot (without extension)
        fontsize: Font size for labels, ticks, and legend
    """
    # Create figure with appropriate size
    plt.figure(figsize=(10, 6), dpi=300)
    
    # Epochs on X-axis
    epochs = range(1, len(history.history['loss']) + 1)
    
    # Plot training and validation loss
    plt.plot(epochs, history.history['loss'], 'o-', color='blue', linewidth=2, 
             markersize=4, label='Training Loss')
    plt.plot(epochs, history.history['val_loss'], 's-', color='red', linewidth=2, 
             markersize=4, label='Validation Loss')
    
    # Labels
    plt.xlabel('Epoch', fontsize=fontsize)
    plt.ylabel('Loss', fontsize=fontsize)
    
    # Integer ticks for epochs
    plt.xticks(ticks=np.arange(0, len(epochs) + 1, 2), fontsize=fontsize)

    plt.yticks(fontsize=fontsize)
    
    # Grid, legend, and ticks
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.legend(fontsize=16, loc='upper right')
    
    plt.minorticks_on()
    plt.tick_params(axis='both', which='minor', length=4, color='gray', labelsize=fontsize)
    plt.tick_params(axis='both', which='major', length=6, color='black', labelsize=fontsize)
    plt.tick_params(top=True, right=True, direction='in', length=6)
    plt.tick_params(which='minor', top=True, right=True, direction='in', length=4)
    
    # Layout and save
    plt.tight_layout()
    if save_path:
        plt.savefig(f"{save_path}.pdf", bbox_inches='tight')
        plt.savefig(f"{save_path}.png", bbox_inches='tight', dpi=300)
        print(f"Loss curves saved to {save_path}.pdf and {save_path}.png")
    
    plt.show()

# %%
# Example usage:
# After training completes
loss_plot_path = 'bendata_regression_frozen_earlystop_mbnetv3small_loss_curves'
plot_loss_curves(history, save_path=loss_plot_path, fontsize=22)
# Out:
# Loss curves saved to bendata_regression_frozen_earlystop_mbnetv3small_loss_curves.pdf and bendata_regression_frozen_earlystop_mbnetv3small_loss_curves.png

# %% [markdown]
# save the full model

# %%
# Save the final model
model_path = '/home/apyba3/PICAR-autopilot/autopilot/models/BenTyler_extradata_v3small/bendata_regression_frozen_earlystop_mbnetv3small_model.keras'
model.save(model_path)
print(f"Final model saved to {model_path}")
# Out:
# Final model saved to /home/apyba3/PICAR-autopilot/autopilot/models/BenTyler_extradata_v3small/bendata_regression_frozen_earlystop_mbnetv3small_model.keras

# %% [markdown]
# save model weights

# %%
model.save_weights('/home/apyba3/PICAR-autopilot/MobNetV3Small_Kaggle/weights/bendata_regression_frozen_earlystop_mbnetv3small_weights.weights.keras')

# %% [markdown]
# clear keras session

# %%
tf.keras.backend.clear_session() #Clear keras session

# %% [markdown]
# ### 2d) fine-tuning

# %% [markdown]
# rebuild model after clearing keras session

# %%
dropoutrate = 0.2
input_shape = (224,224,3)
num_classes = 1 # we're only predicting the prob of the positive class

# %%
# Step 2: Rebuild the model in EXACTLY the same state as when weights were saved
mobnetv3small = tf.keras.applications.MobileNetV3Small(
    weights='imagenet',
    include_top=False,
    input_shape=input_shape
)

# Create model with the SAME architecture as when saving
model = tf.keras.Sequential([
  mobnetv3small,
  tf.keras.layers.GlobalAveragePooling2D(),
  tf.keras.layers.Dropout(dropoutrate),
  tf.keras.layers.Dense(256, activation='relu'),
  tf.keras.layers.Dropout(dropoutrate),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(dropoutrate),
  tf.keras.layers.Dense(64, activation='relu'),
  tf.keras.layers.Dropout(dropoutrate),
  tf.keras.layers.Dense(32, activation='relu'),
  tf.keras.layers.Dense(num_classes, activation='linear')
])

# IMPORTANT: Set trainable to False BEFORE loading weights
# This matches the state when weights were saved
mobnetv3small.trainable = False

# Step 3: Compile the model
# The optimizer doesn't need to match, but having it compiled is important
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    loss=tf.keras.losses.MeanSquaredError(),
)

# Step 4: Load the weights
weights_path = '/home/apyba3/PICAR-autopilot/MobNetV3Small_Kaggle/weights/bendata_regression_frozen_earlystop_mbnetv3small_weights.weights.keras'
model.load_weights(weights_path)

# Step 5: NOW you can set trainable to True for fine-tuning
mobnetv3small.trainable = True

# Step 6: Re-compile with appropriate learning rate for fine-tuning
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    loss=tf.keras.losses.MeanSquaredError(),
)

# Verify model structure
model.summary()

print("Successfully loaded weights and prepared model for fine-tuning!")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  MobilenetV3small (Function  (None, 7, 7, 576)         939120
#  al)
#
#  global_average_pooling2d (  (None, 576)               0
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 576)               0
#
#  dense (Dense)               (None, 256)               147712
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  dense_4 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 1130097 (4.31 MB)
# Trainable params: 1117985 (4.26 MB)
# Non-trainable params: 12112 (47.31 KB)
# _________________________________________________________________
# Successfully loaded weights and prepared model for fine-tuning!

# %% [markdown]
# Initiate fine-tuning training

# %%
class CustomModelCheckpoint(tf.keras.callbacks.Callback):
    def __init__(self, filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min'):
        super(CustomModelCheckpoint, self).__init__()
        self.filepath = filepath
        self.monitor = monitor
        self.verbose = verbose
        self.save_best_only = save_best_only
        
        # Initialize best value based on mode
        self.mode = mode
        if mode == 'min':
            self.best = float('inf')
            self.monitor_op = lambda current, best: current < best
        else:  # 'max'
            self.best = float('-inf')
            self.monitor_op = lambda current, best: current > best
            
    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        current = logs.get(self.monitor)
        
        if current is None:
            if self.verbose > 0:
                print(f"Warning: {self.monitor} not found in logs")
            return
            
        if self.save_best_only:
            if self.monitor_op(current, self.best):
                if self.verbose > 0:
                    print(f"\nEpoch {epoch+1}: {self.monitor} improved from {self.best:.4f} to {current:.4f}")
                    print(f"Saving model to {self.filepath}")
                self.best = current
                
                # Use direct model.save() without extra parameters
                try:
                    self.model.save(self.filepath)
                except Exception as e:
                    print(f"Error saving model: {e}")
        else:
            if self.verbose > 0:
                print(f"\nEpoch {epoch+1}: saving model to {self.filepath}")
            try:
                self.model.save(self.filepath)
            except Exception as e:
                print(f"Error saving model: {e}")

# %%
# Define checkpoint directory and create it if it doesn't exist
checkpoint_dir = '/home/apyba3/PICAR-autopilot/MobNetV3Small_Kaggle/checkpoints'
os.makedirs(checkpoint_dir, exist_ok=True)

# Define checkpoint filepath for the finetuned model
checkpoint_filepath = os.path.join(checkpoint_dir, 'bendata_regression_finetune_earlystop_mbnetv3small_checkpoint.keras')

# Use the existing CustomModelCheckpoint class (no need to redefine it)
# Just create a new instance with the updated filepath
custom_checkpoint = CustomModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_loss',
    save_best_only=True,
    mode='min',
    verbose=1
)

# Define epoch callback 
epoch_callback = LambdaCallback(
    on_epoch_begin=lambda epoch, logs: print(f"\nStarting Epoch {epoch + 1}..."),
    on_epoch_end=lambda epoch, logs: print(f"Completed Epoch {epoch + 1}, Loss: {logs['loss']:.4f}, Val Loss: {logs['val_loss']:.4f}")
)

# Define early stopping callback
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=8,
    min_delta=0.001,
    mode='min',
    restore_best_weights=True,  # This loads the best weights into model memory when stopping
    verbose=1
)

# Train with both callbacks
history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=50,
    callbacks=[custom_checkpoint, epoch_callback, early_stopping]
)
# Out:
# Starting Epoch 1...
# Epoch 1/50
# 870/870 [==============================] - ETA: 0s - loss: 0.1327
# Epoch 1: val_loss improved from inf to 0.0340
# Saving model to /home/apyba3/PICAR-autopilot/MobNetV3Small_Kaggle/checkpoints/bendata_regression_finetune_earlystop_mbnetv3small_checkpoint.keras
# Completed Epoch 1, Loss: 0.1327, Val Loss: 0.0340
# 870/870 [==============================] - 302s 331ms/step - loss: 0.1327 - val_loss: 0.0340
#
# Starting Epoch 2...
# Epoch 2/50
# 870/870 [==============================] - ETA: 0s - loss: 0.0264Completed Epoch 2, Loss: 0.0264, Val Loss: 0.0613
# 870/870 [==============================] - 293s 328ms/step - loss: 0.0264 - val_loss: 0.0613
#
# Starting Epoch 3...
# Epoch 3/50
# 870/870 [==============================] - ETA: 0s - loss: 0.0176Completed Epoch 3, Loss: 0.0176, Val Loss: 0.1508
# 870/870 [==============================] - 292s 327ms/step - loss: 0.0176 - val_loss: 0.1508
#
# Starting Epoch 4...
# Epoch 4/50
# 870/870 [==============================] - ETA: 0s - loss: 0.0134Completed Epoch 4, Loss: 0.0134, Val Loss: 0.0879
# 870/870 [==============================] - 293s 327ms/step - loss: 0.0134 - val_loss: 0.0879
#
# Starting Epoch 5...
# Epoch 5/50
# 870/870 [==============================] - ETA: 0s - loss: 0.0112
# Epoch 5: val_loss improved from 0.0340 to 0.0299
# Saving model to /home/apyba3/PICAR-autopilot/MobNetV3Small_Kaggle/checkpoints/bendata_regression_finetune_earlystop_mbnetv3small_checkpoint.keras
# Completed Epoch 5, Loss: 0.0112, Val Loss: 0.0299
# 870/870 [==============================] - 294s 329ms/step - loss: 0.0112 - val_loss: 0.0299
#
# Starting Epoch 6...
# Epoch 6/50
# 870/870 [==============================] - ETA: 0s - loss: 0.0093
# Epoch 6: val_loss improved from 0.0299 to 0.0239
# Saving model to /home/apyba3/PICAR-autopilot/MobNetV3Small_Kaggle/checkpoints/bendata_regression_finetune_earlystop_mbnetv3small_checkpoint.keras
# Completed Epoch 6, Loss: 0.0093, Val Loss: 0.0239
# 870/870 [==============================] - 293s 328ms/step - loss: 0.0093 - val_loss: 0.0239
#
# Starting Epoch 7...
# Epoch 7/50
# 870/870 [==============================] - ETA: 0s - loss: 0.0085
# Epoch 7: val_loss improved from 0.0239 to 0.0166
# Saving model to /home/apyba3/PICAR-autopilot/MobNetV3Small_Kaggle/checkpoints/bendata_regression_finetune_earlystop_mbnetv3small_checkpoint.keras
# Completed Epoch 7, Loss: 0.0085, Val Loss: 0.0166
# 870/870 [==============================] - 292s 328ms/step - loss: 0.0085 - val_loss: 0.0166
#
# Starting Epoch 8...
# Epoch 8/50
# 870/870 [==============================] - ETA: 0s - loss: 0.0077
# Epoch 8: val_loss improved from 0.0166 to 0.0088
# Saving model to /home/apyba3/PICAR-autopilot/MobNetV3Small_Kaggle/checkpoints/bendata_regression_finetune_earlystop_mbnetv3small_checkpoint.keras
# Completed Epoch 8, Loss: 0.0077, Val Loss: 0.0088
# 870/870 [==============================] - 292s 327ms/step - loss: 0.0077 - val_loss: 0.0088
#
# Starting Epoch 9...
# Epoch 9/50
# 870/870 [==============================] - ETA: 0s - loss: 0.0072Completed Epoch 9, Loss: 0.0072, Val Loss: 0.0166
# 870/870 [==============================] - 292s 328ms/step - loss: 0.0072 - val_loss: 0.0166
#
# Starting Epoch 10...
# Epoch 10/50
# 870/870 [==============================] - ETA: 0s - loss: 0.0068
# Epoch 10: val_loss improved from 0.0088 to 0.0072
# Saving model to /home/apyba3/PICAR-autopilot/MobNetV3Small_Kaggle/checkpoints/bendata_regression_finetune_earlystop_mbnetv3small_checkpoint.keras
# Completed Epoch 10, Loss: 0.0068, Val Loss: 0.0072
# 870/870 [==============================] - 292s 327ms/step - loss: 0.0068 - val_loss: 0.0072
#
# Starting Epoch 11...
# Epoch 11/50
# 870/870 [==============================] - ETA: 0s - loss: 0.0064Completed Epoch 11, Loss: 0.0064, Val Loss: 0.0085
# 870/870 [==============================] - 291s 326ms/step - loss: 0.0064 - val_loss: 0.0085
#
# Starting Epoch 12...
# Epoch 12/50
# 870/870 [==============================] - ETA: 0s - loss: 0.0061Completed Epoch 12, Loss: 0.0061, Val Loss: 0.0110
# 870/870 [==============================] - 294s 327ms/step - loss: 0.0061 - val_loss: 0.0110
#
# Starting Epoch 13...
# Epoch 13/50
# 870/870 [==============================] - ETA: 0s - loss: 0.0058Completed Epoch 13, Loss: 0.0058, Val Loss: 0.0090
# 870/870 [==============================] - 293s 329ms/step - loss: 0.0058 - val_loss: 0.0090
#
# Starting Epoch 14...
# Epoch 14/50
# 870/870 [==============================] - ETA: 0s - loss: 0.0056Completed Epoch 14, Loss: 0.0056, Val Loss: 0.0083
# 870/870 [==============================] - 291s 325ms/step - loss: 0.0056 - val_loss: 0.0083
#
# Starting Epoch 15...
# Epoch 15/50
# 870/870 [==============================] - ETA: 0s - loss: 0.0053Completed Epoch 15, Loss: 0.0053, Val Loss: 0.0122
# 870/870 [==============================] - 291s 326ms/step - loss: 0.0053 - val_loss: 0.0122
#
# Starting Epoch 16...
# Epoch 16/50
# 870/870 [==============================] - ETA: 0s - loss: 0.0052Completed Epoch 16, Loss: 0.0052, Val Loss: 0.0089
# 870/870 [==============================] - 290s 325ms/step - loss: 0.0052 - val_loss: 0.0089
#
# Starting Epoch 17...
# Epoch 17/50
# 870/870 [==============================] - ETA: 0s - loss: 0.0048Completed Epoch 17, Loss: 0.0048, Val Loss: 0.0112
# 870/870 [==============================] - 290s 325ms/step - loss: 0.0048 - val_loss: 0.0112
#
# Starting Epoch 18...
# Epoch 18/50
# 870/870 [==============================] - ETA: 0s - loss: 0.0046Completed Epoch 18, Loss: 0.0046, Val Loss: 0.0140
# Restoring model weights from the end of the best epoch: 10.
# 870/870 [==============================] - 290s 325ms/step - loss: 0.0046 - val_loss: 0.0140
# Epoch 18: early stopping

# %%
# fine tuning results
epochs2 = list(range(1, 19))  # Epochs 1-18
training_loss2 = [0.1327, 0.0264, 0.0176, 0.0134, 0.0112, 0.0093, 0.0085, 0.0077, 
                  0.0072, 0.0068, 0.0064, 0.0061, 0.0058, 0.0056, 0.0053, 0.0052, 
                  0.0048, 0.0046]
validation_loss2 = [0.0340, 0.0613, 0.1508, 0.0879, 0.0299, 0.0239, 0.0166, 0.0088,
                    0.0166, 0.0072, 0.0085, 0.0110, 0.0090, 0.0083, 0.0122, 0.0089,
                    0.0112, 0.0140]

# %%
# This will save the best weights (as already restored by EarlyStopping)
model.save_weights('/home/apyba3/PICAR-autopilot/MobNetV3Small_Kaggle/weights/bendata_regression_finetune_earlystop_mbnetv3small_weights.weights.keras')

# %%
# Example usage:
# After training completes
loss_plot_path = 'bendata_regression_finetune_earlystop_mbnetv3small_loss_curves'
plot_loss_curves(history, save_path=loss_plot_path, fontsize=22)
# Out:
# Loss curves saved to bendata_regression_finetune_earlystop_mbnetv3small_loss_curves.pdf and bendata_regression_finetune_earlystop_mbnetv3small_loss_curves.png

# %% [markdown]
# save the model

# %%
# Save the final model
model_path = '/home/apyba3/PICAR-autopilot/autopilot/models/BenTyler_extradata_v3small/bendata_regression_finetune_earlystop_mbnetv3small_model.keras'
model.save(model_path)
print(f"Final model saved to {model_path}")
# Out:
# Final model saved to /home/apyba3/PICAR-autopilot/autopilot/models/BenTyler_extradata_v3small/bendata_regression_finetune_earlystop_mbnetv3small_model.keras

# %% [markdown]
# # 3) CLASSIFICATION SPEED Test-Set Predictions
#
# a) load in test data
#
# b) convert test images to numerical RGB feature maps
#
# c) generate predictions on the test set
#
# d) correctly format the predictions into a pandas dataframe
#
# e) save predictions to a file inside the hpc (to then later send from hpc to my laptop)

# %% [markdown]
# ### 3a) load in test data

# %%
image_folder_path = '/home/apyba3/KAGGLEDATAmachine-learning-in-science-ii-2025/test_data/test_data'
# image_folder_path = '/home/ppyt13/machine-learning-in-science-ii-2025/test_data/test_data' # tylers file path
image_file_paths = [
    os.path.join(image_folder_path, f)
    for f in os.listdir(image_folder_path)
    if f.lower().endswith(('.png', '.jpg', '.jpeg'))
]

image_file_paths.sort(key=lambda x: int(os.path.splitext(os.path.basename(x))[0])) # sorts the files in the right order (1.png, 2.png, 3.png, ...)

imagefilepaths_df = pd.DataFrame(
    image_file_paths,
    columns=['image_file_paths'],
    index=[int(os.path.splitext(os.path.basename(path))[0]) for path in image_file_paths]
)

imagefilepaths_df.index.name = 'image_id'
imagefilepaths_df.head()
# Out:
#                                                                               image_file_paths
# image_id
# 1         /home/apyba3/KAGGLEDATAmachine-learning-in-science-ii-2025/test_data/test_data/1.png
# 2         /home/apyba3/KAGGLEDATAmachine-learning-in-science-ii-2025/test_data/test_data/2.png
# 3         /home/apyba3/KAGGLEDATAmachine-learning-in-science-ii-2025/test_data/test_data/3.png
# 4         /home/apyba3/KAGGLEDATAmachine-learning-in-science-ii-2025/test_data/test_data/4.png
# 5         /home/apyba3/KAGGLEDATAmachine-learning-in-science-ii-2025/test_data/test_data/5.png

# %% [markdown]
# ### 3b) convert test images to numerical RGB feature maps

# %%
def process_image_no_label(image_path, resized_shape=(224, 224)):
    image = tf.io.read_file(image_path)
    image = tf.image.decode_jpeg(image, channels=3)  # Use decode_png for PNG images
    image = tf.image.resize(image, resized_shape)  # Resize to uniform shape
    image = image / 255.0  # Normalize pixel values to [0,1]
    return image

test_dataset = tf.data.Dataset.from_tensor_slices((imagefilepaths_df["image_file_paths"]))

test_dataset = test_dataset.map(process_image_no_label, num_parallel_calls=tf.data.AUTOTUNE)
test_dataset = test_dataset.batch(BATCH_SIZE)
test_dataset = test_dataset.prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# ### 3c) generate predictions on test set

# %%
predictions = model.predict(test_dataset)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step

# %% [markdown]
# ### 3d) correctly format the predictions into a pandas dataframe

# %%
predictions_df = pd.DataFrame(predictions, columns=['speed'])

# %%
predictions_df.head()
# Out:
#           speed
# 0  1.370914e-25
# 1  1.000000e+00
# 2  9.999998e-01
# 3  1.000000e+00
# 4  9.998439e-01

# %%
predictions_df[predictions_df['speed'] > 0.5] = 1
predictions_df[predictions_df['speed'] < 0.5] = 0

predictions_df['speed'] = predictions_df['speed'].astype(int)

# %%
predictions_df.head()
# Out:
#    speed
# 0      0
# 1      1
# 2      1
# 3      1
# 4      1

# %%
predictions_df['speed'].value_counts()
# Out:
# speed
# 1    516
# 0    504
# Name: count, dtype: int64

# %% [markdown]
# ### 3e) save predictions to a file inside the hpc (to then later send from hpc to my laptop)

# %%
predictions_df.to_csv('/home/apyba3/mobnetv3small_speedclassification_withvalidation_withpetrudata.csv')
